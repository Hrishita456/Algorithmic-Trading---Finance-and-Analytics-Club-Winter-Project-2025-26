# %%
n=int(input())
arr=[]
for i in range(n):
    arr.append(int(input()))
max_v=arr[0]
min_v=arr[0]
for i in range(1,n):
    if arr[i]>max_v: max_v=arr[i]
    if arr[i]<min_v: min_v=arr[i]
print(f"max={max_v} and min={min_v}")

# %%
strn=input()
l=0
r=len(strn)-1
while l<r:
    if strn[l]!=strn[r]:
        print("Given string is not a Palindrome")
        exit(0)
    l+=1
    r-=1
print("Given String is a Palindrome")

# %%
n=int(input())
arr=[]
for i in range(n):
    arr.append(int(input()))
arr.sort()
x=int(input())
a=0
l=0
r=1
b=False
while r<n:
    a=arr[r]-arr[l]
    if a==x:
        print(arr[l],arr[r])
        found=True
    elif a>x: l+=1
    else :r+=1
    if(l==r): r+=1
if not b:
    print("No Such Pair")

# %%
n=int(input())
arr=[]
for i in range(n):
    arr.append(int(input()))
a=int(input())
b=int(input())
c=int(input())
a,b,c=sorted([a,b,c])
l=0
r=n-1
i=0
while i<=r:
    if(b==arr[i]): i+=1
    elif c==arr[i]:
        arr[i],arr[r]=arr[r],arr[i]
        r-=1
    else :
        arr[i],arr[l]=arr[l],arr[i]
        l+=1
        i+=1
print(arr)
